# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/diplomado_cm_ia
# !git config --global user.email "lgarciaag89@gmail.com"
# !git config --global user.name "Luis Antonio Garcia Gonzalez"
# !git add .
# Out:
# /content/drive/MyDrive/diplomado_cm_ia

# %%
# !git add .
# Out:
# fatal: not a git repository (or any of the parent directories): .git
